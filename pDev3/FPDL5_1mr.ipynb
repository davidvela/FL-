# %% [markdown]
# # FP
#
# ## v2 - softmax 2, pandas,
# ## next v3 - GAN , embeddings and visualization:  tensorboard and ...matplot
#
# Start writing all my logic in jupyter notebook in order to run them from anaconda! <br>
# ** IMPORTANT ** <br>
# the network cell should only be intialize once! otherwise the program start creating indexes for the variables!!!!
#
# tensorboard --logdir=.\my_graph
# tensorboard => http://localhost:6006 <br>
# jupyter => http://localhost:8889
#
# ## index:
# <a id='index'/>
#
# 1. READ DATA
#     * Class
#     * files
# 2. [Network](#model)
# 3. [execution](#exec)
# 4. [display](#disp)
#
#
# other:
# 4. [Evaluate](#ev)
# 5. [Test](#ts)
# 6. [Other](#o)
#
# [go back](#index)

# %%
import pandas as pd 
import tensorflow as tf 
import numpy as np 
import matplotlib.pyplot as plt
import itertools

import requests
import json
import sys
import os
import time
from types import *
from collections import Counter
from datetime import datetime

# %%
import utils_data as md

start = time.time()
start
# Out:
# 1523452306.67556

# %%
datetime.now().strftime('%H:%M:%S')
# Out:
# '15:11:46'

# %%
# tensorboard --logdir=.\mygraph

# %% [markdown]
# # Network ops

# %%
def get_nns(): 
    #nns =  str(ninp)+'*'+str(h[0])+'*'+str(h[1])+'*'+str(nout)
    nns =  str(ninp)+'x' 
    for i in range(len(h)):
        nns = nns +str(h[i])+'x'
    return nns +str(nout)
#script hpar (s)
def get_hpar(ep=100, final="_"): return "slr_%.0E_NN%s_ep%s%s" % (lr, get_nns(),str(ep),final)
def logr(datep = '' , time='', it=1000, nn='', typ='TR', DS='', AC=0, num=0, AC3=0, AC10=0, desc='', startTime=''):
    if desc == '': print("Log not recorded"); return 
    LOG = "../../LOGT2.txt"
    f= open(LOG ,"a+") #w,a,
    if datep != '':   dats = datep
    else:             dats = datetime.now().strftime('%d.%m.%Y') 
    if time != '':    times = time
    else:             times = datetime.now().strftime('%H:%M:%S') 

    line =  datetime.now().strftime('%d.%m.%Y') + '\t' + times # time C1,C2
    #v1
    # line = line + '\t' + str(it) + '\t'+  get_nns() +  '\t' + str(lr) # IT NN LR TYP 
    #v2
    line = line + '\t' +  get_hpar(epochs, final=final) + '\t'+ '\t' 
    # values 
    line = line + '\t' + typ + '\t' + str(DS) # type + domain 
    line = line + '\t' + str(AC) + '\t' + str(num) + '\t' + str(AC3) + '\t' +  str(AC10) + '\t' + desc 
    line = line + '\t' + str(batch_size) + '\t' +  startTime + '\n' #new

    f.write(line);  f.close()
    print("___Log recorded")    
def restore_model(sess):   
    saver= tf.train.Saver() 
    print("Model restored from file: %s" % model_path)
    saver.restore(sess, model_path)

# %% [markdown]
# # Network  <a id="model"></a>
# [go back](#index)

# %%
# NETWORK-----------------------------------------------------
def fc(inp, nodes, kp, is_train):
    # h = tf.layers.dense( x, h[0], activation=tf.nn.relu,  name )
    h = tf.layers.dense( inp, nodes, use_bias=False, activation=None )
    if md.dType != "C0": h = tf.layers.batch_normalization(h, training=False)      # CLASS
    h = tf.nn.relu(h)
    if is_train: h = tf.nn.dropout(h, kp)
    return h
def build_network2(is_train=False):     # Simple NN - with batch normalization (high level)
    global top_k

    kp = 0.5
    inp = x
    # h0 = fc(x,  h[0], kp, is_train)
    # h1 = fc(h0, h[1], kp, is_train)    
    with tf.device('/gpu:1'):
        for i in range(len(h)): 
            hx = fc(inp,  h[i], kp, is_train); inp = hx 
        out = tf.layers.dense( hx, nout, use_bias=False, activation=None )
    
    #prediction=tf.reduce_max( y ,1)    # CLASS
    # prediction = out                 # REG

    # softmaxT = tf.nn.softmax(out)
    with tf.name_scope("accuracy"):
        softmaxT = tf.nn.top_k(tf.nn.softmax(out), top_k)                       # CLASS
        # values, indices  = tf.nn.top_k(tf.nn.softmax(out), top_k)             # CLASS
        # prediction_classes = table.lookup(tf.to_int64(indices))
        correct_prediction = tf.equal(tf.argmax(out, 1), tf.argmax(y, 1))       # CLASS
        accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))      # CLASS

        if md.dType == "C0":
            total_error = tf.reduce_sum(tf.square(tf.subtract(y, tf.reduce_mean(y))))        # REG
            unexplained_error = tf.reduce_sum(tf.square(tf.subtract(y, out)))                # REG
            accuracy = tf.subtract(tf.to_float(1), tf.div(total_error, unexplained_error))   # REG

        tf.summary.scalar("accuracy", accuracy)

    return out, accuracy, softmaxT

def build_network3(is_train=False):
    tf.reset_default_graph()

    global prediction, accuracy, softmaxT, cost, summ, optimizer, saver, x, y, confusion

    print("build network")
    with tf.device('/cpu:0'):
        x = tf.placeholder(tf.float32,     shape=[None, ninp], name="x")
        # y = tf.placeholder(tf.int16,     shape=[None, nout], name="y")
        y = tf.placeholder(tf.float32,     shape=[None, nout], name="y")
    
    prediction, accuracy, softmaxT = build_network2(is_train=is_train)
    # confusion = tf.confusion_matrix(labels=y, predictions=prediction, num_classes=nout)
    
    with tf.name_scope("xent"): #loss
        cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=prediction, labels=y))
        if md.dType == "C0": cost = tf.reduce_mean(tf.square(prediction-y) )               # REG
        tf.summary.scalar("xent", cost)
    
    with tf.name_scope("train"): #optimizer
        optimizer = tf.train.AdamOptimizer(learning_rate=lr).minimize(cost)
    
    summ = tf.summary.merge_all()
    saver= tf.train.Saver()

def build_network1( ):
    tf.reset_default_graph()
    global prediction, accuracy, softmaxT, cost, summ, optimizer, saver, x, y, confusion
    print("build network")

    with tf.device('/cpu:0'):
        x = tf.placeholder(tf.float32,     shape=[None, ninp], name="x")
        y = tf.placeholder(tf.float32,     shape=[None, nout], name="y")

    # Simple NN - 2layers - matmul 
    biases  = { 'b1': tf.Variable(tf.random_normal( [ h[0] ]),        name="Bias_1"),
                'b2': tf.Variable(tf.random_normal( [ h[1] ]),        name="Bias_2"),
                'out': tf.Variable(tf.random_normal( [nout] ),        name="Bias_out") }
    weights = { 'h1': tf.Variable(tf.random_normal([ninp,h[0]]),      name="Weights_1"),
                'h2': tf.Variable(tf.random_normal([h[0],h[1]]),      name="Weights_2"),
                'out': tf.Variable(tf.random_normal([h[1], nout]),    name="Weights_out")}
   
    with tf.device('/gpu:1'):
        # tf.reset_default_graph( )
        with tf.name_scope("fc_1"):
            layer_1 = tf.add(tf.matmul(x, weights['h1']), biases['b1'])
            layer_1 = tf.nn.relu(layer_1)
        # Hidden layer with RELU activation
        with tf.name_scope("fc_2"):
            layer_2 = tf.add(tf.matmul(layer_1, weights['h2']), biases['b2'])
            layer_2 = tf.nn.relu(layer_2)
        # Output layer with linear activation
        with tf.name_scope("fc_output"):
            out = tf.matmul(layer_2, weights['out']) + biases['out']
            prediction= out

    #softmaxT = tf.nn.softmax(out, )
    softmaxT = tf.nn.top_k(tf.nn.softmax(out), top_k)   

    with tf.name_scope("accuracy"):
        correct_prediction = tf.equal(tf.argmax(out, 1), tf.argmax(y, 1))
        accuracy = tf.reduce_mean(tf.cast(correct_prediction, tf.float32))
        tf.summary.scalar("accuracy", accuracy)
    
    #return out, accuracy, softmaxT, biases, weights
    
    with tf.name_scope("xent"): #loss
        cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits_v2(logits=prediction, labels=y))
        if md.dType == "C0": cost = tf.reduce_mean(tf.square(prediction-y) )               # REG
        tf.summary.scalar("xent", cost)
    
    with tf.name_scope("train"): #optimizer
        optimizer = tf.train.AdamOptimizer(learning_rate=lr).minimize(cost)
    
    summ = tf.summary.merge_all()
    saver= tf.train.Saver()

# %% [markdown]
# # OPERATIONS

# %%
# OPERATIONS-----------------------------------------------------
def train(it = 100, disp=50, batch_size = 128, compt = False): 
    print("____TRAINING...")
    display_step =  disp 

    dataTest = {'label' : [] , 'data' :  [] }
    if compt: 
        md.get_columns(pp_excel = True )  # True! #md.dsc or dataset? 
        dataTest['data'] = md.dsc.iloc[:, 3:].as_matrix().tolist(); dataTest['label'] = md.dsc.iloc[:, 2].as_matrix().tolist()
     
    print("data read - lenTrain={}-{} & lenEv={}-{}, col = {}" 
            # .format(len(md.dataT["data"]), len(md.dataT["label"]),len(md.dataE["data"]),len(md.dataE["label"]) ))
            .format(len(md.dst.iloc[md.spn:, 3:]), len(md.dst.loc[md.spn:,'FP_P']),
            len( md.dst.iloc[:md.spn, 3:] ),len( md.dst.loc[:md.spn-1,'FP_P'] ), 
            len(dataTest['data'])
             ))
    
    total_batch  = int(len(md.dataT['label']) / batch_size)   
    startTime = datetime.now().strftime('%H:%M:%S')
    stored_ex = None 
    
    tf_config = tf.ConfigProto(allow_soft_placement=True) #,log_device_placement=True)
    tf_config.gpu_options.allow_growth = True
    
    with tf.Session(config=tf_config  ) as sess:
        sess.run(tf.global_variables_initializer())
        # restore_model(sess)  #Run if I want to retrain an existing model  
        writer = tf.summary.FileWriter(md.MODEL_DIR + "/tboard/", sess.graph ) # + get_hpar() )

        start = time.time()
        for i in range(it):  
            try:          
                if stored_ex : print("INT!"); break 
                
                for ii, (xtb,ytb) in enumerate(md.get_batches(batch_size) ):
                    # xtb, ytb = dc.next_batch(batch_size, dataT['data'], dataT['label'])
                    sess.run(optimizer, feed_dict={x: xtb, y: ytb})
                    
                    if ii % display_step ==0: #record_step == 0:
                        #[train_accuracy] = sess.run([accuracy], feed_dict={x: xtb, y: ytb })
                        # s = sess.run(summ, feed_dict={x: xtb, y: ytb })
                        [train_accuracy, s] = sess.run([accuracy, summ], feed_dict={x: xtb, y: ytb }) 
                        writer.add_summary(s, i)
                        
                        elapsed_time = float(time.time() - start)
                        reviews_per_second = i / elapsed_time if elapsed_time > 0 else 0
                        rp_s = str(reviews_per_second)[0:5]
                        tr_ac = str(train_accuracy)[:5]  
                        print('Epoch: {} batch: {} / {} - %Speed(it/disp_step): {} - tr_ac {}' .format(i, ii, total_batch, rp_s, tr_ac ))
                        # writer.add_summary(s, i)
                test_accuracy = sess.run( accuracy, feed_dict={ x: md.dst.iloc[:md.spn, 3:],  y: md.dst.loc[:md.spn-1,'FP_P'].as_matrix().tolist()  })
                ev_ac = str(test_accuracy)[:5]  
                print("E Ac:", ev_ac)
                
                if compt: 
                    sess.run([optimizer], feed_dict={x: dataTest['data'], y: dataTest['label']})
                    tr_ac = str(sess.run(accuracy, feed_dict={x: dataTest['data'], y: dataTest['label']}))[:5] 
                    print("Cm Ac:", tr_ac)
                
                train_accuracy = sess.run( accuracy, feed_dict={ x: md.dst.iloc[md.spn:, 3:],  y: md.dst.loc[md.spn:,'FP_P'].as_matrix().tolist()   })
                tr_ac = str( train_accuracy )[:5] 
                print("T Ac:", tr_ac)
                train_accuracies.append(tr_ac)
                test_accuracies.append(ev_ac)

#                 test_accuracy = sess.run( accuracy, feed_dict={ x: md.dst.iloc[:md.spn, 3:],  y: md.dst.loc[:md.spn-1,'FP_P'].as_matrix().tolist()  })
#                 ev_ac = str(test_accuracy)[:5]  
#                 print("E Ac:", ev_ac)
#                 train_accuracy = sess.run( accuracy, feed_dict={ x: md.dst.iloc[md.spn:, 3:],  y: md.dst.loc[md.spn:,'FP_P'].as_matrix().tolist()   })
#                 tr_ac = str( train_accuracy )[:5] 
#                 print("T Ac:", tr_ac)

            except KeyboardInterrupt: 
                stored_ex = sys.exc_info()
        #end
        save_path = saver.save(sess, model_path)
        print("Model saved in file: %s" % save_path) 
    print("Optimization Finished!")

    logr( it=it, typ='TR', DS=md.DESC, AC=tr_ac,num=len(md.dst)-md.spn, AC3=0, AC10=0, desc=md.des(), startTime=startTime )
    logr( it=it, typ='EV', DS=md.DESC, AC=ev_ac,num=md.spn, AC3=0, AC10=0, desc=md.des() )
    dataTest = {'label' : [] , 'data' :  [] }

def train_opt( ): 
    print("____TRAINING OPT...")
    pass



def clean_traina():
    global train_accuracies, test_accuracies
    train_accuracies, test_accuracies = [], []
    
def vis_chart( ):
    fig, ax = plt.subplots()
    plt.plot(train_accuracies, label='Train', alpha=0.5)
    plt.plot(test_accuracies, label='Test', alpha=0.5)
    plt.title("Accuracy" + md.MODEL_DIR)
    plt.legend()
    # plt.savefig(md.MODEL_DIR + "/chart.png" )
    plt.savefig(md.MODEL_DIR + ".png" )
    # plt.show()
    return

# %% [markdown]
# # Vis and EV

# %%
def evaluate( ): 
    print("_____EVALUATION...")
    startTime = datetime.now().strftime('%H:%M:%S')

    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        restore_model(sess)
        # test the model
        tr_ac = str(sess.run( accuracy, feed_dict={ x: md.dst.iloc[md.spn:, 3:],  y: md.dst.loc[md.spn:,'FP_P'].as_matrix().tolist()    }) )[:5]  
        ev_ac = str(sess.run( accuracy, feed_dict={ x: md.dst.iloc[:md.spn, 3:],  y: md.dst.loc[:md.spn-1,'FP_P'].as_matrix().tolist()  }))[:5] 
        print("Training   Accuracy:", tr_ac )
        print("Evaluation Accuracy:", ev_ac )
        # xtp1.append(dataTest['data'][i]);    ytp1.append(dataTest['label'][i])
        predv, sf = sess.run([prediction, softmaxT], feed_dict={x: md.dst.iloc[:md.spn, 3:]  }) # , y: md.dataE['label'] 
        # maxa = sess.run([prediction], feed_dict={y: predv })
        
    print("Preview the first predictions:")
    for i in range(20):
        print("RealVal: {}  - PP value: {}".format( md.dc( md.dst.loc[:md.spn-1,'FP_P'][i])   , 
                                                    md.dc( predv.tolist()[i], np.max(predv[i]))  ))
    gt3, gtM = md.check_perf_CN(sf, md.dst.loc[:md.spn-1,'FP_P'], False)
    logr(  it=epochs, typ='EV', AC=ev_ac,DS=md.DESC, num=md.spn, AC3=gt3, AC10=gtM, desc=md.des(), startTime=startTime )
    
    calc_confusion_m( sf, md.dst.loc[:md.spn-1,'FP_P'], "EV")

    # return predv.tolist()
    return sf

def tests(url_test = 'url', p_col=False):  
    print("_____TESTS...")    
    
    # Load test data 
    dataTest = {'label' : [] , 'data' :  [] }; pred_val = []
    if p_col:                   # test columns 
        md.get_columns( )  #md.dsc
        dataTest['data'] = md.dsc.iloc[:, 3:].as_matrix().tolist(); dataTest['label'] = md.dsc.iloc[:, 2].as_matrix().tolist()
    elif p_col == False:        # test dataset 
        # logic migrated to get_tests -- 04.02
        # if url_test != 'url':   # test  file 
        #     json_data = url_test + "data_jsonX.txt"
        #     tmpLab = pd.read_csv(url_test + "datalX.csv", sep=',', usecols=[0,1])    
        #     tmpLab = tmpLab.loc[:,'fp']
        #     DESC   = "FREXP1_X"
        # else:                   # get data test JSON = url
        #     json_str, tmpLab = md.get_data_test(md.DESC)
        #     json_data = json.loads(json_str)
        #     DESC =  'matnrList...'
        # force = False

        md.get_tests(url_test ) #dsp
        dataTest['data']  = md.dsp.iloc[:, 3:].as_matrix().tolist(); dataTest['label'] = md.dsp.iloc[:, 2].as_matrix().tolist()     
    # Predict data 
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        restore_model(sess)
        # predv = sess.run( prediction, feed_dict={x: dataTest['data']}) 
        ts_acn = '0'
        ts_acn, predv, sf = sess.run( [accuracy, prediction, softmaxT], feed_dict={x: dataTest['data'], y: dataTest['label']}) 
        ts_ac = str(ts_acn) 
        print("test ac = {}".format(ts_ac))
    
    # print(dataTest['label']);     print(sf)
    range_ts = len(predv) if len(predv)<20 else 20
    for i in range( range_ts ):
        # print("RealVal: {}  - PP value: {}".format( md.dc( dataTest['label'][i]), md.dc( predv.tolist()[i], np.max(predv[i]))  ))  
        print("{} RealVal: {} - {} - PP: {} PR: {}".format( i, md.dc( dataTest['label'][i]), sf[1][i][0],  sf[1][i], sf[0][i]  ))

    # return
    gt3, gtM = md.check_perf_CN(sf, dataTest["label"], False)
    logr( it=0, typ='TS', DS=md.DESC, AC=ts_acn ,num=len(dataTest["label"]),  AC3=gt3, AC10=gtM, desc=md.des() )  

#     calc_confusion_m( sf, md.dsp["FP_P"], "TS" )

    # outfile = md.LOGDAT + 'export2' 
    # np.savetxt(outfile + '.csv', sf[1], delimiter=',')
    # np.savetxt(outfile + 'PRO.csv', sf[0], delimiter=',')
    dataTest = {'label' : [] , 'data' :  [] }; pred_val = []
    return sf

def tests_exec(url_test = 'url', ret_str=True):  
    dataTest = {'label' : [] , 'data' :  [] }; pred_val = []
    # md.get_tests(url_test) #dsp
    tmpLab = [1] # dummy 
    json_str = url_test
    # print(json_str)
    if json_str[0]=="'": 
        json_str = json_str[1:]
        if json_str[len(json_str)-1]=="'": json_str = json_str[:len(json_str)-1]
        json_str = json_str.replace("'", '"')
    json_str = "[" + json_str + "]" 
    # json_str =   '''{ "m":"1", "100023" : 1 }  ''';  json_str = "[" + json_str + "]" 
    # print(json_str)
    json_data = json.loads(json_str)
    # print(json_data)
    md.dsp = md.feed_data(json_data ,pand=True, d_st=True, p_all = True)       #d_st = display status
    ds = md.dsp.iloc[0]
    if len(ds.iloc[ds.nonzero()]) == 1: return "error: comp 0"
    md.dsp["FP"] = tmpLab; 
    md.dsp.insert(2, 'FP_P', md.dsp['FP'].map(lambda x: md.cc( x )))
    dataTest['data']  = md.dsp.iloc[:, 3:].as_matrix().tolist();   # No FP
    dataTest['label'] = md.dsp.iloc[:, 2].as_matrix().tolist()     # dummy 
     
    # md.print_form2(dsp.iloc[0]);     # print(dsp.iloc[0])
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        restore_model(sess)
        # predv = sess.run( prediction, feed_dict={x: dataTest['data']}) 
        predv, sf = sess.run( [ prediction, softmaxT], feed_dict={x: dataTest['data']}) #, y: dataTest['label']}) 

    for i in range( 1 ):
        # print("RealVal: {}  - PP value: {}".format( md.dc( dataTest['label'][i]), md.dc( predv.tolist()[i], np.max(predv[i]))  ))  
        print("{} RealVal: {} - {} - PP: {} PR: {}".format( i, md.dc(dataTest['label'][i]), sf[1][i][0],  sf[1][i], sf[0][i]  ))
    
    logr( it=0, typ='AP', DS=md.DESC, AC=sf[1][0] ,num=sf[0][0],  AC3=0, AC10="real?", desc=str(md.dsp.iloc[0,0] ) )  
    # logr( it=0, typ='TS', DS=md.DESC, AC=ts_acn ,num=len(dataTest["label"]),  AC3=gt3, AC10=gtM, desc=md.des() )  

    # if ret_str: return "PP: {} PR: {}".format(sf[1][0], sf[0][0] )
    if ret_str: return "PP: {} PR: {}".format(sf[1][0], sf[0][0] )
    else: return md.get_json_format(md.dType, sf[1][0], sf[0][0] )

# %%
def vis_confusion_m(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues, 
                          tid="t"):
    plt.figure()
    if md.dType == "C1": 
        fig = plt.gcf()
        fig.set_size_inches(32, 32)
    
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=90)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    #print(cm)

    thresh = cm.max() / 2.

    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')
#     plt.savefig(md.LOGDAT + md.dType + "_" + tid + "conf_mat.png" )
    plt.show()
    # plt.clf()
    # plt.cla()  # for multiple subplots


iccm = 0 
def calc_confusion_m( sf, dst, tid="t"):
    global iccm 
    confusion = tf.confusion_matrix(    labels=md.get_conv_list(  dst ), 
                                        predictions=[ sf[1][x][0]  for x in range( len(sf[1]) )   ], 
                                        num_classes=nout)
    with tf.Session() as sess:
        conf = sess.run(confusion)
   
    np.savetxt(md.LOGDAT + "cm" + tid +".csv", conf, delimiter=",")
    
    if md.dType == "C1N": 
        print(conf)
    else: 
        class_names = [str(i) for i in range(md.nout)]
        vis_confusion_m( conf, classes=class_names, normalize=False,
                            title='Confusion matrix, without normalization',
                            cmap=plt.cm.cool, tid=tid)

# %% [markdown]
# # Network1 - TES

# %%
md.DESC      = "FRALL1" # "FREXP"  FRFLO FRALL1
md.spn       = 10000  
md.dType     = "C1" #C1, C2, C4, C0

#---------------------------------------------------------------
# DATA READ 
#---------------------------------------------------------------
ALL_DS     = md.LOGDAT + md.DESC + md.DSC 
md.mainRead2(ALL_DS, 1, 2, all = True, shuffle = True  ) 
# md.mainRead2(ALL_DS, 1, 2, all = False ) # For testing I am forced to used JSON - column names and order may be different! 
md.normalize()
# Out:
# data read - 45822 - time:30.58809733390808

# %%
epochs       = 100 #100
lr           = 0.001 #0.0001
h            = [1000 , 500]   #[40 , 10]   [200, 100, 40] [100,100]
ninp, nout   = 10, 10
batch_size   = 128
final        = "j" #FF or _

ninp, nout, top_k = md.getnn()
# print(len(md.dst))
md.MODEL_DIR = md.LOGDIR + md.DESC + '/'   + get_hpar(epochs, final=final) +"/" 
model_path = md.MODEL_DIR + "model.ckpt"

# %%
force = True        
url_test = md.LOGDAT + "FREXP1/" ; # url_test = "url"
md.get_tests(url_test=url_test, force=force, pp_excel=True)
# md.get_columns(force, True)

# %%
build_network3()
print(model_path)
print( get_nns() )

md.MODEL_DIR
# Out:
# build network
# ../../dmodels/FRALL1/slr_1E-03_NN2385x1000x500x102_ep100j/model.ckpt
# 2385x1000x500x102
# '../../dmodels/FRALL1/slr_1E-03_NN2385x1000x500x102_ep100j/'

# %% [markdown]
# # EXECUTIONS TR <a id="exec"/>
# [go back](#index)

# %%
def fprint(ds, ds_pred):
    pass

# %%
clean_traina()

# %%
epochs       = 50 #100
disp         = 50
batch_size   = 128
train(epochs, disp, batch_size, True)
# Out:
# ____TRAINING...
# data read - lenTrain=35822-35822 & lenEv=10000-10000, col = 2385
# 35712
# Epoch: 0 batch: 0 / 0 - %Speed(it/disp_step): 0.0 - tr_ac 0.218
# Epoch: 0 batch: 50 / 0 - %Speed(it/disp_step): 0.0 - tr_ac 0.195
# Epoch: 0 batch: 100 / 0 - %Speed(it/disp_step): 0.0 - tr_ac 0.195
# Epoch: 0 batch: 150 / 0 - %Speed(it/disp_step): 0.0 - tr_ac 0.281
# Epoch: 0 batch: 200 / 0 - %Speed(it/disp_step): 0.0 - tr_ac 0.226
# Epoch: 0 batch: 250 / 0 - %Speed(it/disp_step): 0.0 - tr_ac 0.234
# E Ac: 0.277
# Cm Ac: 0.404
# T Ac: 0.286
# 35712
# Epoch: 1 batch: 0 / 0 - %Speed(it/disp_step): 0.086 - tr_ac 0.265
# Epoch: 1 batch: 50 / 0 - %Speed(it/disp_step): 0.075 - tr_ac 0.257
# Epoch: 1 batch: 100 / 0 - %Speed(it/disp_step): 0.067 - tr_ac 0.289
# Epoch: 1 batch: 150 / 0 - %Speed(it/disp_step): 0.060 - tr_ac 0.367
# Epoch: 1 batch: 200 / 0 - %Speed(it/disp_step): 0.054 - tr_ac 0.304
# Epoch: 1 batch: 250 / 0 - %Speed(it/disp_step): 0.050 - tr_ac 0.273
# E Ac: 0.307
# Cm Ac: 0.439
# T Ac: 0.327
# 35712
# Epoch: 2 batch: 0 / 0 - %Speed(it/disp_step): 0.083 - tr_ac 0.320
# Epoch: 2 batch: 50 / 0 - %Speed(it/disp_step): 0.077 - tr_ac 0.351
# Epoch: 2 batch: 100 / 0 - %Speed(it/disp_step): 0.072 - tr_ac 0.312
# Epoch: 2 batch: 150 / 0 - %Speed(it/disp_step): 0.068 - tr_ac 0.367
# Epoch: 2 batch: 200 / 0 - %Speed(it/disp_step): 0.064 - tr_ac 0.320
# Epoch: 2 batch: 250 / 0 - %Speed(it/disp_step): 0.060 - tr_ac 0.343
# E Ac: 0.315
# Cm Ac: 0.453
# T Ac: 0.344
# 35712
# Epoch: 3 batch: 0 / 0 - %Speed(it/disp_step): 0.081 - tr_ac 0.335
# Epoch: 3 batch: 50 / 0 - %Speed(it/disp_step): 0.078 - tr_ac 0.351
# Epoch: 3 batch: 100 / 0 - %Speed(it/disp_step): 0.075 - tr_ac 0.320
# Epoch: 3 batch: 150 / 0 - %Speed(it/disp_step): 0.072 - tr_ac 0.382
# Epoch: 3 batch: 200 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.335
# Epoch: 3 batch: 250 / 0 - %Speed(it/disp_step): 0.066 - tr_ac 0.359
# E Ac: 0.321
# Cm Ac: 0.481
# T Ac: 0.356
# 35712
# Epoch: 4 batch: 0 / 0 - %Speed(it/disp_step): 0.081 - tr_ac 0.367
# Epoch: 4 batch: 50 / 0 - %Speed(it/disp_step): 0.078 - tr_ac 0.375
# Epoch: 4 batch: 100 / 0 - %Speed(it/disp_step): 0.075 - tr_ac 0.343
# Epoch: 4 batch: 150 / 0 - %Speed(it/disp_step): 0.073 - tr_ac 0.382
# Epoch: 4 batch: 200 / 0 - %Speed(it/disp_step): 0.071 - tr_ac 0.351
# Epoch: 4 batch: 250 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.351
# E Ac: 0.325
# Cm Ac: 0.524
# T Ac: 0.368
# 35712
# Epoch: 5 batch: 0 / 0 - %Speed(it/disp_step): 0.081 - tr_ac 0.382
# Epoch: 5 batch: 50 / 0 - %Speed(it/disp_step): 0.078 - tr_ac 0.382
# Epoch: 5 batch: 100 / 0 - %Speed(it/disp_step): 0.076 - tr_ac 0.367
# Epoch: 5 batch: 150 / 0 - %Speed(it/disp_step): 0.074 - tr_ac 0.414
# Epoch: 5 batch: 200 / 0 - %Speed(it/disp_step): 0.073 - tr_ac 0.375
# Epoch: 5 batch: 250 / 0 - %Speed(it/disp_step): 0.071 - tr_ac 0.382
# E Ac: 0.328
# Cm Ac: 0.565
# T Ac: 0.385
# 35712
# Epoch: 6 batch: 0 / 0 - %Speed(it/disp_step): 0.080 - tr_ac 0.398
# Epoch: 6 batch: 50 / 0 - %Speed(it/disp_step): 0.078 - tr_ac 0.390
# Epoch: 6 batch: 100 / 0 - %Speed(it/disp_step): 0.076 - tr_ac 0.390
# Epoch: 6 batch: 150 / 0 - %Speed(it/disp_step): 0.074 - tr_ac 0.437
# Epoch: 6 batch: 200 / 0 - %Speed(it/disp_step): 0.073 - tr_ac 0.406
# Epoch: 6 batch: 250 / 0 - %Speed(it/disp_step): 0.071 - tr_ac 0.421
# E Ac: 0.335
# Cm Ac: 0.608
# T Ac: 0.406
# 35712
# Epoch: 7 batch: 0 / 0 - %Speed(it/disp_step): 0.079 - tr_ac 0.421
# Epoch: 7 batch: 50 / 0 - %Speed(it/disp_step): 0.077 - tr_ac 0.406
# Epoch: 7 batch: 100 / 0 - %Speed(it/disp_step): 0.075 - tr_ac 0.406
# Epoch: 7 batch: 150 / 0 - %Speed(it/disp_step): 0.074 - tr_ac 0.414
# Epoch: 7 batch: 200 / 0 - %Speed(it/disp_step): 0.072 - tr_ac 0.429
# Epoch: 7 batch: 250 / 0 - %Speed(it/disp_step): 0.071 - tr_ac 0.5
# E Ac: 0.335
# Cm Ac: 0.649
# T Ac: 0.421
# 35712
# Epoch: 8 batch: 0 / 0 - %Speed(it/disp_step): 0.078 - tr_ac 0.445
# Epoch: 8 batch: 50 / 0 - %Speed(it/disp_step): 0.076 - tr_ac 0.414
# Epoch: 8 batch: 100 / 0 - %Speed(it/disp_step): 0.075 - tr_ac 0.453
# Epoch: 8 batch: 150 / 0 - %Speed(it/disp_step): 0.073 - tr_ac 0.406
# Epoch: 8 batch: 200 / 0 - %Speed(it/disp_step): 0.072 - tr_ac 0.445
# Epoch: 8 batch: 250 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.5
# E Ac: 0.334
# Cm Ac: 0.688
# T Ac: 0.434
# 35712
# Epoch: 9 batch: 0 / 0 - %Speed(it/disp_step): 0.076 - tr_ac 0.460
# Epoch: 9 batch: 50 / 0 - %Speed(it/disp_step): 0.075 - tr_ac 0.429
# Epoch: 9 batch: 100 / 0 - %Speed(it/disp_step): 0.074 - tr_ac 0.476
# Epoch: 9 batch: 150 / 0 - %Speed(it/disp_step): 0.072 - tr_ac 0.414
# Epoch: 9 batch: 200 / 0 - %Speed(it/disp_step): 0.071 - tr_ac 0.445
# Epoch: 9 batch: 250 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.531
# E Ac: 0.336
# Cm Ac: 0.716
# T Ac: 0.448
# 35712
# Epoch: 10 batch: 0 / 0 - %Speed(it/disp_step): 0.075 - tr_ac 0.460
# Epoch: 10 batch: 50 / 0 - %Speed(it/disp_step): 0.074 - tr_ac 0.414
# Epoch: 10 batch: 100 / 0 - %Speed(it/disp_step): 0.073 - tr_ac 0.515
# Epoch: 10 batch: 150 / 0 - %Speed(it/disp_step): 0.072 - tr_ac 0.421
# Epoch: 10 batch: 200 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.460
# Epoch: 10 batch: 250 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.531
# E Ac: 0.339
# Cm Ac: 0.737
# T Ac: 0.467
# 35712
# Epoch: 11 batch: 0 / 0 - %Speed(it/disp_step): 0.074 - tr_ac 0.468
# Epoch: 11 batch: 50 / 0 - %Speed(it/disp_step): 0.073 - tr_ac 0.453
# Epoch: 11 batch: 100 / 0 - %Speed(it/disp_step): 0.072 - tr_ac 0.539
# Epoch: 11 batch: 150 / 0 - %Speed(it/disp_step): 0.071 - tr_ac 0.445
# Epoch: 11 batch: 200 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.476
# Epoch: 11 batch: 250 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.523
# E Ac: 0.345
# Cm Ac: 0.756
# T Ac: 0.492
# 35712
# Epoch: 12 batch: 0 / 0 - %Speed(it/disp_step): 0.074 - tr_ac 0.5
# Epoch: 12 batch: 50 / 0 - %Speed(it/disp_step): 0.073 - tr_ac 0.492
# Epoch: 12 batch: 100 / 0 - %Speed(it/disp_step): 0.072 - tr_ac 0.562
# Epoch: 12 batch: 150 / 0 - %Speed(it/disp_step): 0.071 - tr_ac 0.484
# Epoch: 12 batch: 200 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.492
# Epoch: 12 batch: 250 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.546
# E Ac: 0.346
# Cm Ac: 0.771
# T Ac: 0.516
# 35712
# Epoch: 13 batch: 0 / 0 - %Speed(it/disp_step): 0.073 - tr_ac 0.531
# Epoch: 13 batch: 50 / 0 - %Speed(it/disp_step): 0.072 - tr_ac 0.554
# Epoch: 13 batch: 100 / 0 - %Speed(it/disp_step): 0.071 - tr_ac 0.578
# Epoch: 13 batch: 150 / 0 - %Speed(it/disp_step): 0.071 - tr_ac 0.492
# Epoch: 13 batch: 200 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.5
# Epoch: 13 batch: 250 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.578
# E Ac: 0.349
# Cm Ac: 0.795
# T Ac: 0.532
# 35712
# Epoch: 14 batch: 0 / 0 - %Speed(it/disp_step): 0.073 - tr_ac 0.507
# Epoch: 14 batch: 50 / 0 - %Speed(it/disp_step): 0.072 - tr_ac 0.531
# Epoch: 14 batch: 100 / 0 - %Speed(it/disp_step): 0.071 - tr_ac 0.578
# Epoch: 14 batch: 150 / 0 - %Speed(it/disp_step): 0.071 - tr_ac 0.515
# Epoch: 14 batch: 200 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.523
# Epoch: 14 batch: 250 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.617
# E Ac: 0.346
# Cm Ac: 0.808
# T Ac: 0.550
# 35712
# Epoch: 15 batch: 0 / 0 - %Speed(it/disp_step): 0.072 - tr_ac 0.531
# Epoch: 15 batch: 50 / 0 - %Speed(it/disp_step): 0.072 - tr_ac 0.531
# Epoch: 15 batch: 100 / 0 - %Speed(it/disp_step): 0.071 - tr_ac 0.617
# Epoch: 15 batch: 150 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.539
# Epoch: 15 batch: 200 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.531
# Epoch: 15 batch: 250 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.609
# E Ac: 0.344
# Cm Ac: 0.825
# T Ac: 0.564
# 35712
# Epoch: 16 batch: 0 / 0 - %Speed(it/disp_step): 0.072 - tr_ac 0.554
# Epoch: 16 batch: 50 / 0 - %Speed(it/disp_step): 0.072 - tr_ac 0.562
# Epoch: 16 batch: 100 / 0 - %Speed(it/disp_step): 0.071 - tr_ac 0.609
# Epoch: 16 batch: 150 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.570
# Epoch: 16 batch: 200 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.539
# Epoch: 16 batch: 250 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.625
# E Ac: 0.341
# Cm Ac: 0.834
# T Ac: 0.575
# 35712
# Epoch: 17 batch: 0 / 0 - %Speed(it/disp_step): 0.072 - tr_ac 0.546
# Epoch: 17 batch: 50 / 0 - %Speed(it/disp_step): 0.071 - tr_ac 0.585
# Epoch: 17 batch: 100 / 0 - %Speed(it/disp_step): 0.071 - tr_ac 0.648
# Epoch: 17 batch: 150 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.585
# Epoch: 17 batch: 200 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.570
# Epoch: 17 batch: 250 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.656
# E Ac: 0.341
# Cm Ac: 0.844
# T Ac: 0.586
# 35712
# Epoch: 18 batch: 0 / 0 - %Speed(it/disp_step): 0.072 - tr_ac 0.546
# Epoch: 18 batch: 50 / 0 - %Speed(it/disp_step): 0.071 - tr_ac 0.609
# Epoch: 18 batch: 100 / 0 - %Speed(it/disp_step): 0.071 - tr_ac 0.664
# Epoch: 18 batch: 150 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.617
# Epoch: 18 batch: 200 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.554
# Epoch: 18 batch: 250 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.664
# E Ac: 0.338
# Cm Ac: 0.853
# T Ac: 0.585
# 35712
# Epoch: 19 batch: 0 / 0 - %Speed(it/disp_step): 0.072 - tr_ac 0.593
# Epoch: 19 batch: 50 / 0 - %Speed(it/disp_step): 0.071 - tr_ac 0.671
# Epoch: 19 batch: 100 / 0 - %Speed(it/disp_step): 0.071 - tr_ac 0.664
# Epoch: 19 batch: 150 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.625
# Epoch: 19 batch: 200 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.578
# Epoch: 19 batch: 250 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.664
# E Ac: 0.333
# Cm Ac: 0.859
# T Ac: 0.579
# 35712
# Epoch: 20 batch: 0 / 0 - %Speed(it/disp_step): 0.071 - tr_ac 0.593
# Epoch: 20 batch: 50 / 0 - %Speed(it/disp_step): 0.071 - tr_ac 0.687
# Epoch: 20 batch: 100 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.625
# Epoch: 20 batch: 150 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.656
# Epoch: 20 batch: 200 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.570
# Epoch: 20 batch: 250 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.648
# E Ac: 0.335
# Cm Ac: 0.864
# T Ac: 0.611
# 35712
# Epoch: 21 batch: 0 / 0 - %Speed(it/disp_step): 0.071 - tr_ac 0.601
# Epoch: 21 batch: 50 / 0 - %Speed(it/disp_step): 0.071 - tr_ac 0.671
# Epoch: 21 batch: 100 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.679
# Epoch: 21 batch: 150 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.671
# Epoch: 21 batch: 200 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.625
# Epoch: 21 batch: 250 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.664
# E Ac: 0.334
# Cm Ac: 0.870
# T Ac: 0.642
# 35712
# Epoch: 22 batch: 0 / 0 - %Speed(it/disp_step): 0.071 - tr_ac 0.625
# Epoch: 22 batch: 50 / 0 - %Speed(it/disp_step): 0.071 - tr_ac 0.695
# Epoch: 22 batch: 100 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.718
# Epoch: 22 batch: 150 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.687
# Epoch: 22 batch: 200 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.656
# Epoch: 22 batch: 250 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.695
# E Ac: 0.332
# Cm Ac: 0.875
# T Ac: 0.664
# 35712
# Epoch: 23 batch: 0 / 0 - %Speed(it/disp_step): 0.071 - tr_ac 0.648
# Epoch: 23 batch: 50 / 0 - %Speed(it/disp_step): 0.071 - tr_ac 0.75
# Epoch: 23 batch: 100 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.726
# Epoch: 23 batch: 150 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.726
# Epoch: 23 batch: 200 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.687
# Epoch: 23 batch: 250 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.718
# E Ac: 0.325
# Cm Ac: 0.884
# T Ac: 0.676
# 35712
# Epoch: 24 batch: 0 / 0 - %Speed(it/disp_step): 0.071 - tr_ac 0.648
# Epoch: 24 batch: 50 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.773
# Epoch: 24 batch: 100 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.734
# Epoch: 24 batch: 150 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.734
# Epoch: 24 batch: 200 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.718
# Epoch: 24 batch: 250 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.710
# E Ac: 0.321
# Cm Ac: 0.893
# T Ac: 0.678
# 35712
# Epoch: 25 batch: 0 / 0 - %Speed(it/disp_step): 0.071 - tr_ac 0.671
# Epoch: 25 batch: 50 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.773
# Epoch: 25 batch: 100 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.742
# Epoch: 25 batch: 150 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.734
# Epoch: 25 batch: 200 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.726
# Epoch: 25 batch: 250 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.695
# E Ac: 0.317
# Cm Ac: 0.898
# T Ac: 0.682
# 35712
# Epoch: 26 batch: 0 / 0 - %Speed(it/disp_step): 0.071 - tr_ac 0.671
# Epoch: 26 batch: 50 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.812
# Epoch: 26 batch: 100 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.757
# Epoch: 26 batch: 150 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.75
# Epoch: 26 batch: 200 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.765
# Epoch: 26 batch: 250 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.718
# E Ac: 0.317
# Cm Ac: 0.901
# T Ac: 0.688
# 35712
# Epoch: 27 batch: 0 / 0 - %Speed(it/disp_step): 0.071 - tr_ac 0.687
# Epoch: 27 batch: 50 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.796
# Epoch: 27 batch: 100 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.773
# Epoch: 27 batch: 150 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.765
# Epoch: 27 batch: 200 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.781
# Epoch: 27 batch: 250 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.718
# E Ac: 0.320
# Cm Ac: 0.905
# T Ac: 0.700
# 35712
# Epoch: 28 batch: 0 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.726
# Epoch: 28 batch: 50 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.796
# Epoch: 28 batch: 100 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.796
# Epoch: 28 batch: 150 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.789
# Epoch: 28 batch: 200 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.765
# Epoch: 28 batch: 250 / 0 - %Speed(it/disp_step): 0.068 - tr_ac 0.734
# E Ac: 0.322
# Cm Ac: 0.910
# T Ac: 0.713
# 35712
# Epoch: 29 batch: 0 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.765
# Epoch: 29 batch: 50 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.820
# Epoch: 29 batch: 100 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.796
# Epoch: 29 batch: 150 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.804
# Epoch: 29 batch: 200 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.742
# Epoch: 29 batch: 250 / 0 - %Speed(it/disp_step): 0.068 - tr_ac 0.765
# E Ac: 0.328
# Cm Ac: 0.913
# T Ac: 0.731
# 35712
# Epoch: 30 batch: 0 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.796
# Epoch: 30 batch: 50 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.843
# Epoch: 30 batch: 100 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.796
# Epoch: 30 batch: 150 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.804
# Epoch: 30 batch: 200 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.75
# Epoch: 30 batch: 250 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.765
# E Ac: 0.327
# Cm Ac: 0.920
# T Ac: 0.734
# 35712
# Epoch: 31 batch: 0 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.789
# Epoch: 31 batch: 50 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.843
# Epoch: 31 batch: 100 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.796
# Epoch: 31 batch: 150 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.789
# Epoch: 31 batch: 200 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.773
# Epoch: 31 batch: 250 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.789
# E Ac: 0.324
# Cm Ac: 0.919
# T Ac: 0.723
# 35712
# Epoch: 32 batch: 0 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.789
# Epoch: 32 batch: 50 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.843
# Epoch: 32 batch: 100 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.820
# Epoch: 32 batch: 150 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.734
# Epoch: 32 batch: 200 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.796
# Epoch: 32 batch: 250 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.781
# E Ac: 0.326
# Cm Ac: 0.917
# T Ac: 0.731
# 35712
# Epoch: 33 batch: 0 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.796
# Epoch: 33 batch: 50 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.835
# Epoch: 33 batch: 100 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.828
# Epoch: 33 batch: 150 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.765
# Epoch: 33 batch: 200 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.781
# Epoch: 33 batch: 250 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.757
# E Ac: 0.324
# Cm Ac: 0.924
# T Ac: 0.755
# 35712
# Epoch: 34 batch: 0 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.804
# Epoch: 34 batch: 50 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.851
# Epoch: 34 batch: 100 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.859
# Epoch: 34 batch: 150 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.789
# Epoch: 34 batch: 200 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.765
# Epoch: 34 batch: 250 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.765
# E Ac: 0.318
# Cm Ac: 0.925
# T Ac: 0.763
# 35712
# Epoch: 35 batch: 0 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.828
# Epoch: 35 batch: 50 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.851
# Epoch: 35 batch: 100 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.859
# Epoch: 35 batch: 150 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.796
# Epoch: 35 batch: 200 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.789
# Epoch: 35 batch: 250 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.804
# E Ac: 0.316
# Cm Ac: 0.925
# T Ac: 0.778
# 35712
# Epoch: 36 batch: 0 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.843
# Epoch: 36 batch: 50 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.890
# Epoch: 36 batch: 100 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.875
# Epoch: 36 batch: 150 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.804
# Epoch: 36 batch: 200 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.781
# Epoch: 36 batch: 250 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.796
# E Ac: 0.311
# Cm Ac: 0.927
# T Ac: 0.776
# 35712
# Epoch: 37 batch: 0 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.851
# Epoch: 37 batch: 50 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.906
# Epoch: 37 batch: 100 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.867
# Epoch: 37 batch: 150 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.835
# Epoch: 37 batch: 200 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.789
# Epoch: 37 batch: 250 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.820
# E Ac: 0.308
# Cm Ac: 0.930
# T Ac: 0.774
# 35712
# Epoch: 38 batch: 0 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.867
# Epoch: 38 batch: 50 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.929
# Epoch: 38 batch: 100 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.882
# Epoch: 38 batch: 150 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.835
# Epoch: 38 batch: 200 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.804
# Epoch: 38 batch: 250 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.820
# E Ac: 0.293
# Cm Ac: 0.927
# T Ac: 0.760
# 35712
# Epoch: 39 batch: 0 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.843
# Epoch: 39 batch: 50 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.929
# Epoch: 39 batch: 100 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.890
# Epoch: 39 batch: 150 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.851
# Epoch: 39 batch: 200 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.812
# Epoch: 39 batch: 250 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.812
# E Ac: 0.292
# Cm Ac: 0.926
# T Ac: 0.744
# 35712
# Epoch: 40 batch: 0 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.804
# Epoch: 40 batch: 50 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.914
# Epoch: 40 batch: 100 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.867
# Epoch: 40 batch: 150 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.851
# Epoch: 40 batch: 200 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.796
# Epoch: 40 batch: 250 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.796
# E Ac: 0.303
# Cm Ac: 0.927
# T Ac: 0.776
# 35712
# Epoch: 41 batch: 0 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.843
# Epoch: 41 batch: 50 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.906
# Epoch: 41 batch: 100 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.867
# Epoch: 41 batch: 150 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.835
# Epoch: 41 batch: 200 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.843
# Epoch: 41 batch: 250 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.812
# E Ac: 0.307
# Cm Ac: 0.928
# T Ac: 0.797
# 35712
# Epoch: 42 batch: 0 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.875
# Epoch: 42 batch: 50 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.921
# Epoch: 42 batch: 100 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.914
# Epoch: 42 batch: 150 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.867
# Epoch: 42 batch: 200 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.867
# Epoch: 42 batch: 250 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.851
# E Ac: 0.308
# Cm Ac: 0.928
# T Ac: 0.800
# 35712
# Epoch: 43 batch: 0 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.875
# Epoch: 43 batch: 50 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.921
# Epoch: 43 batch: 100 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.890
# Epoch: 43 batch: 150 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.859
# Epoch: 43 batch: 200 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.843
# Epoch: 43 batch: 250 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.851
# E Ac: 0.307
# Cm Ac: 0.930
# T Ac: 0.802
# 35712
# Epoch: 44 batch: 0 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.882
# Epoch: 44 batch: 50 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.921
# Epoch: 44 batch: 100 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.882
# Epoch: 44 batch: 150 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.859
# Epoch: 44 batch: 200 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.882
# Epoch: 44 batch: 250 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.890
# E Ac: 0.306
# Cm Ac: 0.936
# T Ac: 0.808
# 35712
# Epoch: 45 batch: 0 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.898
# Epoch: 45 batch: 50 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.898
# Epoch: 45 batch: 100 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.867
# Epoch: 45 batch: 150 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.859
# Epoch: 45 batch: 200 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.882
# Epoch: 45 batch: 250 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.921
# E Ac: 0.305
# Cm Ac: 0.934
# T Ac: 0.810
# 35712
# Epoch: 46 batch: 0 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.898
# Epoch: 46 batch: 50 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.929
# Epoch: 46 batch: 100 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.875
# Epoch: 46 batch: 150 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.875
# Epoch: 46 batch: 200 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.882
# Epoch: 46 batch: 250 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.906
# E Ac: 0.304
# Cm Ac: 0.939
# T Ac: 0.821
# 35712
# Epoch: 47 batch: 0 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.890
# Epoch: 47 batch: 50 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.921
# Epoch: 47 batch: 100 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.914
# Epoch: 47 batch: 150 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.867
# Epoch: 47 batch: 200 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.890
# Epoch: 47 batch: 250 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.898
# E Ac: 0.305
# Cm Ac: 0.937
# T Ac: 0.823
# 35712
# Epoch: 48 batch: 0 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.898
# Epoch: 48 batch: 50 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.929
# Epoch: 48 batch: 100 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.929
# Epoch: 48 batch: 150 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.875
# Epoch: 48 batch: 200 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.906
# Epoch: 48 batch: 250 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.914
# E Ac: 0.307
# Cm Ac: 0.937
# T Ac: 0.832
# 35712
# Epoch: 49 batch: 0 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.898
# Epoch: 49 batch: 50 / 0 - %Speed(it/disp_step): 0.070 - tr_ac 0.937
# Epoch: 49 batch: 100 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.921
# Epoch: 49 batch: 150 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.867
# Epoch: 49 batch: 200 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.898
# Epoch: 49 batch: 250 / 0 - %Speed(it/disp_step): 0.069 - tr_ac 0.929
# E Ac: 0.304
# Cm Ac: 0.936
# T Ac: 0.837
# Model saved in file: ../../dmodels/FRALL1/slr_1E-03_NN2385x1000x500x102_ep100j/model.ckpt
# Optimization Finished!
# ___Log recorded
# ___Log recorded

# %% [markdown]
# # EXECUTIONS EV

# %%
evd = evaluate( )
# Out:
# _____EVALUATION...
# Model restored from file: ../../dmodels/FRALL1/slr_1E-03_NN2385x1000x500x102_ep100j/model.ckpt
# INFO:tensorflow:Restoring parameters from ../../dmodels/FRALL1/slr_1E-03_NN2385x1000x500x102_ep100j/model.ckpt
# Training   Accuracy: 0.816
# Evaluation Accuracy: 0.308
# Preview the first predictions:
# RealVal: 80  - PP value: 79
# RealVal: 101  - PP value: 101
# RealVal: 101  - PP value: 101
# RealVal: 97  - PP value: 98
# RealVal: 97  - PP value: 96
# RealVal: 62  - PP value: 63
# RealVal: 101  - PP value: 101
# RealVal: 67  - PP value: 64
# RealVal: 101  - PP value: 101
# RealVal: 65  - PP value: 65
# RealVal: 88  - PP value: 94
# RealVal: 93  - PP value: 95
# RealVal: 101  - PP value: 101
# RealVal: 48  - PP value: 48
# RealVal: 74  - PP value: 73
# RealVal: 96  - PP value: 96
# RealVal: 97  - PP value: 101
# RealVal: 101  - PP value: 97
# RealVal: 84  - PP value: 84
# RealVal: 90  - PP value: 90
# denormalization all Evaluation : 10000 = 10000
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# Total: 10000 GT3: 2317  GTM: 641
# ___Log recorded
# Confusion matrix, without normalization

# %%
# fprint(ran, data, pred)

# %% [markdown]
# # Ex Test

# %%
# md.dsp
sft = tests(url_test, p_col=False  )
# vis_chart( )
# Out:
# _____TESTS...
# Model restored from file: ../../dmodels/FRALL1/slr_1E-03_NN2385x1000x500x102_ep100j/model.ckpt
# INFO:tensorflow:Restoring parameters from ../../dmodels/FRALL1/slr_1E-03_NN2385x1000x500x102_ep100j/model.ckpt
# test ac = 0.53181386
# 0 RealVal: 70 - 73 - PP: [73 76 68 74 79] PR: [9.0510517e-01 9.4006874e-02 4.0859924e-04 2.2699157e-04 1.2232742e-04]
# 1 RealVal: 74 - 74 - PP: [74 77 76 72 78] PR: [0.80008155 0.10965993 0.083283   0.00371944 0.0018251 ]
# 2 RealVal: 67 - 70 - PP: [70 72 73 93 74] PR: [9.9983883e-01 6.7056440e-05 3.2674125e-05 3.2316751e-05 1.3907217e-05]
# 3 RealVal: 67 - 68 - PP: [68 64 60 67 71] PR: [9.7571057e-01 2.2268448e-02 6.5930875e-04 5.0135708e-04 3.6027018e-04]
# 4 RealVal: 97 - 97 - PP: [ 97 101  94  96 100] PR: [0.87102044 0.05255626 0.02467271 0.01375415 0.01227917]
# 5 RealVal: 66 - 93 - PP: [93 71 68 70 67] PR: [0.8372036  0.10779797 0.02665918 0.00729093 0.00593633]
# 6 RealVal: 65 - 93 - PP: [93 68 67 66 64] PR: [0.5722147  0.1651701  0.06936882 0.05536105 0.0530379 ]
# 7 RealVal: 101 - 101 - PP: [101  98  99  97 100] PR: [9.9786538e-01 1.8394669e-03 1.9495077e-04 3.6585443e-05 2.9737459e-05]
# 8 RealVal: 86 - 88 - PP: [88 89 86 87 91] PR: [9.9216002e-01 6.9968998e-03 5.2327575e-04 1.2707115e-04 1.1393539e-04]
# 9 RealVal: 88 - 88 - PP: [88 89 86 87 91] PR: [0.7961818  0.13226487 0.04208692 0.02085835 0.00554373]
# 10 RealVal: 91 - 94 - PP: [94 92 89 91 95] PR: [0.9025065  0.03337026 0.02596277 0.01636666 0.00941765]
# 11 RealVal: 92 - 92 - PP: [92 93 98 97 96] PR: [0.9048513  0.05256645 0.02805509 0.00446114 0.00439539]
# 12 RealVal: 80 - 80 - PP: [80 79 77 76 78] PR: [0.9180587  0.06383365 0.013094   0.00127456 0.00110004]
# 13 RealVal: 66 - 69 - PP: [69 68 64 65 61] PR: [0.4905754  0.20578006 0.11891421 0.10757326 0.05519279]
# 14 RealVal: 69 - 68 - PP: [68 71 69 67 72] PR: [0.36387557 0.3285051  0.19739962 0.10294564 0.00234489]
# 15 RealVal: 48 - 51 - PP: [51 52 48 54 42] PR: [0.959962   0.01582551 0.01464481 0.00285744 0.00229292]
# 16 RealVal: 51 - 51 - PP: [51 54 52 50 48] PR: [0.95042837 0.01674811 0.01386524 0.00857612 0.0035967 ]
# 17 RealVal: 72 - 72 - PP: [72 75 73 74 76] PR: [0.94107413 0.03041052 0.01442165 0.00529977 0.00401515]
# 18 RealVal: 71 - 71 - PP: [71 73 68 74 70] PR: [0.5270021  0.34799907 0.10124173 0.00648014 0.00466746]
# 19 RealVal: 83 - 83 - PP: [83 80 77 82 73] PR: [0.63230765 0.3273698  0.02373847 0.01388053 0.00102447]
# denormalization all Evaluation : 1053 = 1053
# 0
# 1000
# Total: 1053 GT3: 85  GTM: 12
# ___Log recorded

# %%
# print(dataTest['data'])
# sft[1][0][0]
# [ sft[1][x][0]  for x in range( len(sft[1]) )   ]

# %%
fig, ax = plt.subplots()
fig.set_size_inches(20, 20)
plt.plot(train_accuracies, label='Train', alpha=0.5)
plt.plot(test_accuracies, label='Test', alpha=0.5)
plt.title("Accuracy"+model_path)
plt.legend()
# plt.show()
# plt.savefig(md.MODEL_DIR + "chart.png" )

# %% [markdown]
# # 1RUN

# %%
import mRun as mr
execc = [
            { 'dt':'C2',  "e":100, "lr":0.001, "h":[100 , 100], "spn": 5000, "pe": [], "pt": []  },
            { 'dt':'C4',  "e":100, "lr":0.001, "h":[100 , 100], "spn": 5000, "pe": [], "pt": []  },
            { 'dt':'C1',  "e":100, "lr":0.001, "h":[100 , 100], "spn": 5000, "pe": [], "pt": []  },
        ]

final = "_" ;  md.DESC = "FRAFLO";  # FRFLO   FRALL1
ALL_DS = md.LOGDAT + md.DESC + md.DSC

# %%
# DATA READ 
# md.mainRead2(ALL_DS, 1, 2 ) # , all = True, shuffle = True  ) 
md.mainRead2(path=ALL_DS, part=1, batch_size=2 ) # For testing I am forced to used JSON - column names and order may be different! 
url_test = md.LOGDAT + "FREXP1/" ; # url_test = "url"
force = False; excel = True  # dataFile = "frall2_json.txt"; labelFile = "datal.csv"     
md.get_tests(url_test, force, excel )

# %%
for ex in execc:
    md.spn = ex["spn"]; md.dType = ex["dt"]; mr.epochs = ex["e"]

    md.normalize()
    mr.ninp, mr.nout, mr.top_k = md.getnn()
    md.MODEL_DIR = md.LOGDIR + md.DESC + '/'   + mr.get_hpar(mr.epochs, final=final) +"/" 
    mr.model_path = md.MODEL_DIR + "model.ckpt" 
    mr.build_network3()
    print(mr.model_path)    

    # mr.evaluate( )

    ex["pt"] = mr.tests(url_test, p_col=False  )

# %%
print("0<60_1>60__0<23_1<60_2<93_3>93  ")
for i in range(20):
    print("m:{0:15} - R-{4:5}   ||    P1-{1:2}         P2-{2:2}        P3-{3}" 
    .format(md.dsp.iloc[i,0], execc[0]["pt"][1][i][0], execc[1]["pt"][1][i][0],  execc[2]["pt"][1][i], md.dsp.iloc[i,1], ))

# %% [markdown]
# # Embedding by FAM
# get data / get FAM <br>
# if am > 0 => 1; lookup tab.  => visualization embeddings in script.

# %%
#logic...

# %% [markdown]
# # WRITE EXCEL

# %%
# import xlsxwriter
# outfile = '../../_zfp/data/export.xlsx' 

# workbook   = xlsxwriter.Workbook(outfile)
# worksheet1 = workbook.add_worksheet()
# worksheet1.write('A1', 'M')
# worksheet1.write(0, 0, 'Hello')  
# for i in range(len(sf[0])):
#     worksheet1.write(0, i , sf[0][i])  
#     worksheet1.write(1, i , sf[1][i])

# %%
# import csv
# outfile = '../../_zfp/data/export.csv' 
# f2= open(outfile,"a+")
# output_writer = csv.writer(f2, delimiter="\t")
# output_writer.writerows(sf)
# f2.close()

# %%
# outfile = '../../_zfp/data/export2' 
# np.savetxt(outfile + '.csv', sf[1], delimiter=',')
# np.savetxt(outfile + 'PRO.csv', sf[0], delimiter=',')

# %% [markdown]
# # Display visualizations <a id="disp"/>
# [go back](#index)

# %%
# path = outfile = '../../_zfp/data/FRFLO/datasc.csv' 
# dst  =  pd.read_csv( tf.gfile.Open(path), sep=None, skipinitialspace=True,  engine="python")
Y  = dst.loc[:,'FP'].as_matrix().tolist()
X  = dst.loc[:, 'M'].as_matrix().tolist()

# %%
# 2 - Create plot. 
a = 1
if a == 0: 
    plt.hist(Y)
else: 
    plt.xlabel('M')
    plt.ylabel('FP')
    plt.grid(True)
    N = 2 #50
    colors = np.random.rand(N)
    area = 1 #np.pi * (15 * np.random.rand(N))**2  # 0 to 15 point radii

    #plt.plot(X, Y, color='blue', marker='o', label='FP Comp')
    #plt.plot(X, Y, 'bo', label='FP Comp')
    plt.scatter(X,Y, s=6, c='b', marker='o', cmap=None, norm=None, vmin=60, vmax=101, alpha=None,  label='FP Comp')
    # plt.plot(X, Y,  s=area, c=colors, alpha=0.5) #'bo', label='FP Comp',
    plt.legend()

# 3 - Display plot. 

plt.show()
